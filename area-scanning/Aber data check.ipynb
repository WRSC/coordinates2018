# %%
import folium
from glob import glob
from IPython.display import HTML, display
import os.path as osp
import pandas
import yaml

# %%
calshot_latlon = [50.820483, -1.311233]

# %%
markers = pandas.read_csv('../area_scanning.csv', index_col=0)
markers
# Out:
#              lat       lon
# point
# A      50.821073 -1.314657
# B      50.822221 -1.312855
# C      50.819602 -1.312321
# D      50.820750 -1.310520

# %%
start_icon = folium.Icon(color='green', icon='play')

# %% [markdown]
# ## Second attempt
#
# With GPS data from team (official tracker failed).

# %%
boat_trace = pandas.read_csv('aber-own-gps/AberSailbot-AreaScan-Attempt2.csv')

# Create the map
map_osm = folium.Map(location=calshot_latlon, zoom_start=17)

# Add the corner markers
corners = [(markers.loc[p].lat, markers.loc[p].lon) for p in 'ABDC']
folium.features.PolygonMarker(corners, fill_opacity=0.25).add_to(map_osm)

# Add the boat track
latlons = [(row.latitude, row.longitude) for row in boat_trace.itertuples()]
map_osm.add_child(folium.features.PolyLine(latlons))

# Mark which end is the start 
start = boat_trace.iloc[0]
folium.Marker(latlons[0], icon=start_icon).add_to(map_osm)
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## First attempt
#
# With official tracker

# %%
boat_trace = pandas.read_csv('Aberystwyth1.csv')

# Create the map
map_osm = folium.Map(location=calshot_latlon, zoom_start=17)

# Add the corner markers
corners = [(markers.loc[p].lat, markers.loc[p].lon) for p in 'ABDC']
folium.features.PolygonMarker(corners, fill_opacity=0.25).add_to(map_osm)

# Add the boat track
latlons = [(row.latitude, row.longitude) for row in boat_trace.itertuples()]
map_osm.add_child(folium.features.PolyLine(latlons))

# Mark which end is the start 
start = boat_trace.iloc[0]
folium.Marker((start.latitude, start.longitude), icon=start_icon).add_to(map_osm)
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# The window for this attempt officially closed at 13:00 UTC (14:00 local). How does this affect the track?

# %%
boat_trace_inwindow = boat_trace[boat_trace.datetime < '2018-08-29T13:00:00Z']  # Compare datetime to str. Ugly but handy.

# Create the map
map_osm = folium.Map(location=calshot_latlon, zoom_start=17)

# Add the corner markers
corners = [(markers.loc[p].lat, markers.loc[p].lon) for p in 'ABDC']
folium.features.PolygonMarker(corners, fill_opacity=0.25).add_to(map_osm)

# Add the boat track
latlons = [(row.latitude, row.longitude) for row in boat_trace_inwindow.itertuples()]
map_osm.add_child(folium.features.PolyLine(latlons))

# Mark which end is the start 
start = boat_trace_inwindow.iloc[0]
folium.Marker((start.latitude, start.longitude), icon=start_icon).add_to(map_osm)
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
